# %%
#teilt alle excel in dem ordner durch vier 
# überprüft den Abstand der Zeitreihen, sind die aufeinanderfolgenden Zeiten im 5 Minuten- oder 15 Minutentakt hinterlegt?
import os
import pandas as pd
import xlsxwriter
import datetime

# introduction of Datetime to access the time
now=datetime.datetime.now().strftime('%Y-%m-%d')

# setting display options for Jupyter output
pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 2)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 2000)

# directory of source files
path=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\Viertelstunden_Next"

for file in os.listdir(path):
    # list of months
    mon_list=[]
    # DataFrame for a month
    df_mon=pd.DataFrame([])
    csv_path=path+"\\"+file
    # reading a source file
    # numbers are separated by commas as decimal points
    df=pd.read_csv(csv_path, delimiter=";", decimal=",")

    path_neu = r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\VR_Neu"
    
    # dividing column [1] by 4
    df[df.columns[1]]=df[df.columns[1]].div(4)
    # splitting .csv as a filename
    file=file.split(".")
    file=file[0]
    path_vr= path_neu+"\\"+now+"_neu_"+"_"+file+".xlsx"
    df.to_excel(path_vr)
    list_series=df.iloc[:,0].tolist()
    mon_a=int(list_series[0].split(":")[1])
    mon_b=int(list_series[1].split(":")[1])
    print(mon_a)
    if mon_a-mon_b == 15:
        print("good")
    else:
        print(file +" bad")
    
    #except:
       # print("error")

# %%
#umbennenungstool python, ersetzt Jan-Mär mit Dez-Mär
import os
import shutil
old_string= "Jan-Mär"
new_string="Dez-Mär"
patha=r"U:\x Abschöpfung\Grundlagendaten Ben"
for file in os.listdir(patha):
    if old_string in file:
        new_filename=file.replace(old_string, new_string)
        print(new_filename)
        os.rename(os.path.join(patha, file), os.path.join(patha,new_filename))

# %%
#legt die Strom PBG Datei in allen Ziel-Ordnern ab
#ablege datei muss erst aktiviert werden, damit nix überschrieben wird

import os
import pandas as pd
import shutil
import datetime
name="StromPBG_Referenzberechnungstool_2023.03_V3"
# directory of source files
now=datetime.datetime.now().strftime('%Y-%m-%d')
path=r"U:\x Abschöpfung"
datei=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\{}.xlsx".format(name)
folder = os.listdir(path)
for file in folder:
    file_list=file.split(" ")
    print((file_list[0]))
    if int(file_list[0])>=0:
        print("größer")
        print(file)
       # os.remove(path+"\\"+file+"\\"+"2023-04-28"+" "+file+" {}.xlsx".format(name))
        dest_path=path+"\\"+file+"\\"+now+" "+file+"{}.xlsx".format(name)
        shutil.copyfile(datei,dest_path)
    else:
        print("kleiner")

# %%
#dieser Code zerschneidet eine PDF und teilt sie in Intervalle auf

from PyPDF2 import PdfWriter, PdfReader
import datetime

#Zeiteinheit wird gezogen
now=datetime.datetime.now().strftime('%Y-%m-%d')
len_p=5
path=r"C:\Users\benjamin.schmitz\Downloads\2023-04-20 50Hertz Transmission an Wattner - StromPBG - Information zum Registrierungsprozess bei 50Hertz Transmission.pdf"
#path=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\20221213_11h05 Uhr-Synopse-StromPBG_synops_20221213_110550.pdf"
inputpdf =PdfReader(open(path, "rb"))
outp_path=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\Output"
for i in range(0,len(inputpdf.pages),len_p):
    output=PdfWriter()
    for j in range(i, min(i+len_p, len(inputpdf.pages))):
        output.add_page(inputpdf.pages[j])
    with open(outp_path+"\\"+now+" Hertz Transmission an SKW {}-{} - StromPBG - Information zum Registrierungsprozess bei 50Hertz Transmission .pdf".format(i, i+(len_p)),"wb") as outputStream:
        output.write(outputStream)

# %%
PBG.drop(PBG.loc[PBG["Unnamed: 1"]=="Bitte auswählen"].index, inplace=True)
PBG
# Out:
#         Unnamed: 0                                         Unnamed: 1  \
# 0              NaN                                ABR-Nummer (MaStR):
# 1              NaN                                             Monat:
# 2              NaN                                              Jahr:
# 3              NaN                                                NaN
# 4              NaN  Hinweis: Sofern die Rechengeschwindigkeit zu g...
# 5              NaN                                                NaN
# 6  lfd. Nr. Anlage    Auswahl Anwendungsfall §16 StromPBG\n(Dropdown)
# 7                1      EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV
# 8                2      EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV
#
#                              Unnamed: 2  \
# 0                       ABR932982794809
# 1                                     3
# 2                                  2023
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6  MaStR-Nummer der Einheit \n(SEE-Nr.)
# 7                       SEE924145308404
# 8                       SEE901957520323
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  MaStR- Nummer der EEG-/KWK-Anlage  (EEG-/KWK-Nr.)
# 7                                    EEG956067353286
# 8                                    EEG987052019221
#
#                              Unnamed: 4  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6  vorgegebene Referenz-kosten (ct/kWh)
# 7                                     0
# 8                                     0
#
#                                           Unnamed: 5  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  optional:\nmanuelle Referenz-kosten 1 / fixe M...
# 7                                              28.83
# 8                                              28.83
#
#                                   Unnamed: 6  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6  optional:\nBeginn Zeitraum 2 (dd.mm.yyyy)
# 7                                        NaN
# 8                                        NaN
#
#                                         Unnamed: 7  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6  optional:\nmanuelle Referenz-kosten 2\n(ct/kWh)
# 7                                              NaN
# 8                                              NaN
#
#                         Unnamed: 8                 Unnamed: 9  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# 5                              NaN                        NaN
# 6  Sicherheits-marge Spot (ct/kWh)  Monats-marktwert (ct/kWh)
# 7                          3.53298                      8.883
# 8                          3.53298                      8.883
#
#         Unnamed: 10              Unnamed: 11  \
# 0               NaN                      NaN
# 1               NaN                      NaN
# 2               NaN                      NaN
# 3               NaN                      NaN
# 4               NaN                      NaN
# 5               NaN                      NaN
# 6  Wind oder Solar?  Wahlrecht § 18 StromPBG
# 7                ja                  inaktiv
# 8                ja                  inaktiv
#
#                                          Unnamed: 12  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  erforderlich bei Wahlrecht § 18 StromPBG: \nIB...
# 7                                                NaN
# 8                                                NaN
#
#                                          Unnamed: 13  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  erforderlich bei Wahlrecht § 18 StromPBG: \nWu...
# 7                                               nein
# 8                                               nein
#
#                                          Unnamed: 14  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  erforderlich bei Wahlrecht § 18 StromPBG: \nLe...
# 7                                                NaN
# 8                                                NaN
#
#                              Unnamed: 15      Unnamed: 16  \
# 0                                    NaN              NaN
# 1                                    NaN              NaN
# 2                                    NaN              NaN
# 3                                    NaN              NaN
# 4                                    NaN              NaN
# 5                                    NaN              NaN
# 6  Wahlrecht  § 16 Abs. 3 Nr. 2 StromPBG  EUA-Preis [€/t]
# 7                                  aktiv              NaN
# 8                                  aktiv              NaN
#
#                Unnamed: 17             Unnamed: 18  \
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4                      NaN                     NaN
# 5                      NaN                     NaN
# 6  Summe Zählerdaten (kWh)  Summe Redispatch (kWh)
# 7                        0                       0
# 8                        0                       0
#
#                                          Unnamed: 19  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  Weitere abschöpfungs-relevante Erlösbestandtei...
# 7                                                NaN
# 8                                                NaN
#
#                                          Unnamed: 20  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  Monatliche Überschusserlöse § 16 u. § 18 Strom...
# 7                                                  0
# 8                                                  0
#
#                                          Unnamed: 21  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  Ergebnis aus Absicherungs-geschäften (Hedging)...
# 7                                                NaN
# 8                                                NaN
#
#                                          Unnamed: 22  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  Ergebnis aus Absicherungs-geschäften (Hedging)...
# 7                                                NaN
# 8                                                NaN
#
#                                          Unnamed: 23  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  Monatlicher abzu-schöpfender Gesamterlös gem. ...
# 7                                                  0
# 8                                                  0
#
#                                          Unnamed: 24  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  falls abweichend von Referenzrechnung: Monatli...
# 7                                                NaN
# 8                                                NaN
#
#                                          Unnamed: 25        Unnamed: 26
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4                                                NaN                NaN
# 5                                                NaN                NaN
# 6  falls abweichend von Referenzrechnung: Monatli...  optional: Hinweis
# 7                                                NaN
# 8                                                NaN

# %%
df=pd.DataFrame(PBG.loc[5])
display(df)
display(PBG)

# %%
no1="04"

# %%
#### öffnet zwei neue Dateien und schließt und speichert zwei Alte

import os
import shutil
import pandas as pd
import win32com.client
import os
import openpyxl
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.options.display.width=0
path_grund=r"U:\x Abschöpfung\Grundlagendaten Ben"
path_PBG=r"U:\x Abschöpfung"
month="Dez"


#if month== "Dez":
#    Einspeisung="Einspeisung Dez"
#    vers="2022.12_V1"
#elif month== "Jan":
#    Einspeisung="Einspeisung Jan\n"
#    vers="2023.01_V2"
#elif month== "Feb":
#    Einspeisung="Einspeisung Feb"
#    vers="2023.02_V3"
#elif month== "Mär":
#    Einspeisung="Einspeisung Mär"
#    vers="2023.03_V3"
#
#general="Dez-Mär"
#
Einspeisung_l=["Einspeisung Dez","Einspeisung Jan\n","Einspeisung Feb" ,"Einspeisung Mär"]
no2=" 0"+str(no1)
no3="SK0"+str(no1)
#neue nummer wird nach Nummerngröße vergeben, da unterschiedliche Bezeichnungen existieren
excel=win32com.client.Dispatch("Excel.Application")


path_markt_akt=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\2023-04-13 Wattner - Abschöpfung - Marktakteure.xlsx"
path_PBG_ben=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\2023-03-14 Wattner - Abschöpfung nach StromPBG Benb.xlsm"
Leistung_list=[]
SEE= []
EEG= []
Ref1=[]
MGM =[]
Einspeisung_Dez=[]
Einspeisung_Jan=[]
Einspeisung_Feb=[]
Einspeisung_Mär=[]

gesammt_kosten=[]
prozent_Leistung=[]
Anlage=[]
name=[]
workbook = None
dfl=pd.DataFrame(columns=["Einspeisung_Dez","Einspeisung_Jan", "Einspeisung_Feb","Einspeisung_Mär"])
#die excel mit den marktakteuren wird eingelesen

markt_akt=pd.read_excel(path_markt_akt)#,sheet_name="2023-04-13 Wattner - Abschöpfung - Marktakteure
#die excel mit den anlagen wird eingelesen

PGB_ben=pd.read_excel(path_PBG_ben,sheet_name="Alle Anlagen", header=2)
for index, row in markt_akt.iterrows():
    
    #die Marktakteure werden geladen und die MaStR-Nr wird in einer Variabel hinterlegt
    if no2 in row["Name des Marktakteurs"]:
        Mastr= markt_akt.loc[index,"MaStR-Nr."]
        print(Mastr)
        
for index, row in PGB_ben.iterrows():
    if pd.isna(row["Anlagenbetreiber"]):
        continue
    if no3 in row["Anlagenbetreiber"]:
        SEE.append(PGB_ben.loc[index,"MaStR-Nr. der SEE:"])
        EEG.append(PGB_ben.loc[index,"MaStR-Nr. der EEG-Anlage:"])
        Ref1= PGB_ben.loc[index,"anzulegender Wert\nEUR/kWh\n(ohne Managementprämie)"]
        if Ref1 == "fällt raus, da < 1 MW":
            Ref1=0
        MGM = PGB_ben.loc[index,"Managementprämie\nEUR/kWh"]
        if MGM == "fällt raus, da < 1 MW":
            MGM=0
        Leistung_list.append((PGB_ben.loc[index,"DC-Leistung in kWp"]))
        gesammt_kosten.append(float(Ref1+MGM)*100)
        Name = str(row["Teilanlage"])+" "+str(row["Anlagenbetreiber"])
        name.append(Name)
        for i in Einspeisung_l:
            #print(i)
            Einspeisung_Dez.append(PGB_ben.loc[index,i])
            #Einspeisung_Jan.append(PGB_ben.loc[index,i])
            #Einspeisung_Feb.append(PGB_ben.loc[index,i])
            #Einspeisung_Mär.append(PGB_ben.loc[index,i])
            #print(Einspeisung_Dez)
        mid=pd.DataFrame([Einspeisung_Dez], columns=["Einspeisung_Dez","Einspeisung_Jan", "Einspeisung_Feb","Einspeisung_Mär"])
        dfl=pd.concat([dfl,mid], ignore_index=True, axis=0)
        Einspeisung_Dez=[]
for i in Leistung_list:        
    prozent_Leistung.append(i/sum(Leistung_list))
#print(SEE)
#print(EEG)
#print(gesammt_kosten)      
#print(Leistung_list)
#print(sum(Leistung_list))
#print(prozent_Leistung)
#print(Mastr)
#for file in os.listdir(path_grund):
#    if no2 in file and month in file or no2 in file and general in file:
#        new_path_gr = path_grund+"\\"+file
#        
#        print(file)
#        #os.startfile(new_path_gr)
#        print(" ")
#   
#for root, dirs, files in os.walk(path_PBG):
#    # die Datei für die Abschöpfung wird geöffnet
#    for file in files:
#        #die Datei mit der richtigen Nummer und version erhält die richtigen nummern
#        if str(no1) in file and vers in file and str(no1) in root:
#            print("PGB Datei")
#            print(root)
#            print(file)
#    
#              
#            path_PBG_final=os.path.join(root, file)
#          
#            right_file = file
#            print("Right_File")
#            print(right_file)
#           # os.startfile(path_PBG_final)
            
Gesammelte_Daten=pd.DataFrame(list(zip(name, SEE, EEG,gesammt_kosten,Leistung_list,prozent_Leistung )), columns=["Name","SEE","EEG","Kosten","Leistung", "Leistung %",])
#Einspeisung_Dez
Gesammelte_Daten2=pd.concat([Gesammelte_Daten,dfl],axis=1)
#"Einspeisung_Dez","Einspeisung_Jan", "Einspeisung_Feb","Einspeisung_Mär"
display(Gesammelte_Daten2)
#diese Programm öffnet mehrere Dateien in einem Ordner, kopiert Daten aus den Datein in einen Dataframe,
#zeigt den benannten Dataframe und vergleicht den Input miteinandern


#alle Warnungen werden ignoriert   

path_Absch =r"U:\x Abschöpfung"
no=no1

for i in os.listdir(path_Absch):
    if no in i:
        new_path=(path_Absch+"\\"+i)
        for j in os.listdir(new_path):
            if "StromPBG_Referenzberechnungstool" in j:
                print(j)
               
                PBG=pd.read_excel(new_path+"\\"+j, sheet_name="Deckblatt", header=0)
               
                df_rel=PBG.iloc[:,[1,2,3,5,17]]
          
                df_rel.drop(df_rel.loc[df_rel["Unnamed: 1"]=="Bitte auswählen"].index, inplace=True)
                df_rel=df_rel.drop([1,2,3,4,5],axis=0)
                display(df_rel)
no1=int(no1)
i+=1
print(str(no1))
no1="0"+str(no1)
print(no1)
# Out:
# ABR950374308779
# Einspeisung Dez
# [38737]
# Einspeisung Jan
#
# [38737, 36918]
# Einspeisung Feb
# [38737, 36918, 102786]
# Einspeisung Mär
# [38737, 36918, 102786, 153520]
#                    Name              SEE              EEG  Kosten  Leistung  \
# 0  PVA Hasselberg SK004  SEE985151889271  EEG994789236494   28.83  2065.455
#
#    Leistung % Einspeisung_Dez Einspeisung_Jan Einspeisung_Feb Einspeisung_Mär
# 0         1.0           38737           36918          102786          153520
# 2023-04-17 004 Hasselberg StromPBG_Referenzberechnungstool_2022_12_V1.xlsx
#                                         Unnamed: 1  \
# 0                              ABR-Nummer (MaStR):
# 6  Auswahl Anwendungsfall §16 StromPBG\n(Dropdown)
# 7    EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV
#
#                              Unnamed: 2  \
# 0                       ABR950374308779
# 6  MaStR-Nummer der Einheit \n(SEE-Nr.)
# 7                       SEE985151889271
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 6  MaStR- Nummer der EEG-/KWK-Anlage  (EEG-/KWK-Nr.)
# 7                                    EEG994789236494
#
#                                           Unnamed: 5              Unnamed: 17
# 0                                                NaN                      NaN
# 6  optional:\nmanuelle Referenz-kosten 1 / fixe M...  Summe Zählerdaten (kWh)
# 7                                              28.83                 38737.36
# 2023-04-24 04 Hasselberg StromPBG_Referenzberechnungstool_2023.01_V2-b.xlsx
#                                         Unnamed: 1  \
# 0                              ABR-Nummer (MaStR):
# 6  Auswahl Anwendungsfall §16 StromPBG\n(Dropdown)
# 7    EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV
#
#                              Unnamed: 2  \
# 0                       ABR950374308779
# 6  MaStR-Nummer der Einheit \n(SEE-Nr.)
# 7                       SEE985151889271
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 6  MaStR- Nummer der EEG-/KWK-Anlage  (EEG-/KWK-Nr.)
# 7                                    EEG994789236494
#
#                                           Unnamed: 5              Unnamed: 17
# 0                                                NaN                      NaN
# 6  optional:\nmanuelle Referenz-kosten 1 / fixe M...  Summe Zählerdaten (kWh)
# 7                                              28.43                 36917.92
# 2023-05-02 04 HasselbergStromPBG_Referenzberechnungstool_2023.02_V3.xlsx
#                                         Unnamed: 1  \
# 0                              ABR-Nummer (MaStR):
# 6  Auswahl Anwendungsfall §16 StromPBG\n(Dropdown)
# 7    EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV
#
#                              Unnamed: 2  \
# 0                       ABR950374308779
# 6  MaStR-Nummer der Einheit \n(SEE-Nr.)
# 7                       SEE985151889271
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 6  MaStR- Nummer der EEG-/KWK-Anlage  (EEG-/KWK-Nr.)
# 7                                    EEG994789236494
#
#                                           Unnamed: 5              Unnamed: 17
# 0                                                NaN                      NaN
# 6  optional:\nmanuelle Referenz-kosten 1 / fixe M...  Summe Zählerdaten (kWh)
# 7                                              28.83                102785.88
# 2023-05-08 04 HasselbergStromPBG_Referenzberechnungstool_2023.03_V3.xlsx
#                                         Unnamed: 1  \
# 0                              ABR-Nummer (MaStR):
# 6  Auswahl Anwendungsfall §16 StromPBG\n(Dropdown)
# 7    EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV
#
#                              Unnamed: 2  \
# 0                       ABR950374308779
# 6  MaStR-Nummer der Einheit \n(SEE-Nr.)
# 7                       SEE985151889271
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 6  MaStR- Nummer der EEG-/KWK-Anlage  (EEG-/KWK-Nr.)
# 7                                    EEG994789236494
#
#                                           Unnamed: 5              Unnamed: 17
# 0                                                NaN                      NaN
# 6  optional:\nmanuelle Referenz-kosten 1 / fixe M...  Summe Zählerdaten (kWh)
# 7                                              28.83                153519.76
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18236\548450374.py in <module>
#     159                 df_rel=df_rel.drop([1,2,3,4,5],axis=0)
#     160                 display(df_rel)
# --> 161 no1+=1
#
# TypeError: can only concatenate str (not "int") to str

# %%
i="01"

# %%
# Out:
# 5

# %%
# Out:
# 2023-04-17 004 Hasselberg StromPBG_Referenzberechnungstool_2022_12_V1.xlsx
#                                         Unnamed: 1  \
# 0                              ABR-Nummer (MaStR):
# 6  Auswahl Anwendungsfall §16 StromPBG\n(Dropdown)
# 7    EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV
#
#                              Unnamed: 2  \
# 0                       ABR950374308779
# 6  MaStR-Nummer der Einheit \n(SEE-Nr.)
# 7                       SEE985151889271
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 6  MaStR- Nummer der EEG-/KWK-Anlage  (EEG-/KWK-Nr.)
# 7                                    EEG994789236494
#
#                              Unnamed: 4              Unnamed: 17
# 0                                   NaN                      NaN
# 6  vorgegebene Referenz-kosten (ct/kWh)  Summe Zählerdaten (kWh)
# 7                                     0                 38737.36
# 2023-04-24 04 Hasselberg StromPBG_Referenzberechnungstool_2023.01_V2-b.xlsx
#                                         Unnamed: 1  \
# 0                              ABR-Nummer (MaStR):
# 6  Auswahl Anwendungsfall §16 StromPBG\n(Dropdown)
# 7    EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV
#
#                              Unnamed: 2  \
# 0                       ABR950374308779
# 6  MaStR-Nummer der Einheit \n(SEE-Nr.)
# 7                       SEE985151889271
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 6  MaStR- Nummer der EEG-/KWK-Anlage  (EEG-/KWK-Nr.)
# 7                                    EEG994789236494
#
#                              Unnamed: 4              Unnamed: 17
# 0                                   NaN                      NaN
# 6  vorgegebene Referenz-kosten (ct/kWh)  Summe Zählerdaten (kWh)
# 7                                     0                 36917.92
# 2023-05-02 04 HasselbergStromPBG_Referenzberechnungstool_2023.02_V3.xlsx
#                                         Unnamed: 1  \
# 0                              ABR-Nummer (MaStR):
# 6  Auswahl Anwendungsfall §16 StromPBG\n(Dropdown)
# 7    EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV
#
#                              Unnamed: 2  \
# 0                       ABR950374308779
# 6  MaStR-Nummer der Einheit \n(SEE-Nr.)
# 7                       SEE985151889271
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 6  MaStR- Nummer der EEG-/KWK-Anlage  (EEG-/KWK-Nr.)
# 7                                    EEG994789236494
#
#                              Unnamed: 4              Unnamed: 17
# 0                                   NaN                      NaN
# 6  vorgegebene Referenz-kosten (ct/kWh)  Summe Zählerdaten (kWh)
# 7                                     0                102785.88
# 2023-05-08 04 HasselbergStromPBG_Referenzberechnungstool_2023.03_V3.xlsx
#                                         Unnamed: 1  \
# 0                              ABR-Nummer (MaStR):
# 6  Auswahl Anwendungsfall §16 StromPBG\n(Dropdown)
# 7    EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV
#
#                              Unnamed: 2  \
# 0                       ABR950374308779
# 6  MaStR-Nummer der Einheit \n(SEE-Nr.)
# 7                       SEE985151889271
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 6  MaStR- Nummer der EEG-/KWK-Anlage  (EEG-/KWK-Nr.)
# 7                                    EEG994789236494
#
#                              Unnamed: 4              Unnamed: 17
# 0                                   NaN                      NaN
# 6  vorgegebene Referenz-kosten (ct/kWh)  Summe Zählerdaten (kWh)
# 7                                     0                153519.76

# %%
pd.set_option('display.max_columns', None)
PGB_ben.head()

# %%
#öffnet file mit bestimmtem namen
import os
import shutil
stat=0
#search_string ="VNB 02.2023"
search_string ="Gefell"
SKW="028"
path_skw=r"Z:\Belege 2023"
for folder in os.listdir(path_skw):
    if SKW in folder:
        new_path="Z:\Belege 2023"+"\\"+folder
        for root, dirs, files in os.walk(new_path):
            for file in files:
                if search_string in file:
                    final_path=os.path.join(root,file)
                    print(final_path)
                    os.startfile(final_path) 
                    stat=1
                    
if stat==0:
    print("Beleg nicht vorhanden")
    os.startfile(new_path)

# %%
os.startfile(path_grund)
os.startfile(path_PBG)
os.startfile(r"U:\x Abschöpfung\_Tabellen Wattner")

# %%
#löscht bestimmte zeilen in einer Excel

from openpyxl import load_workbook
path=r"C:\Users\benjamin.schmitz\Downloads\zeitreihen-pv-wattner079-202303011400-202304011300.xlsx"
workbook = load_workbook(filename=path)


sheet = workbook.active

for i in range(2975, 2984):
    print(i)
    sheet["A"+str(i)]=""
    sheet["B"+str(i)]=""
    sheet["C"+str(i)]=""
    
for i in range(5950, 5965):
    print(i)
    sheet["A"+str(i)]=""
    sheet["B"+str(i)]=""
    sheet["C"+str(i)]=""
for i in range(8640, 8650):
    print(i)
    sheet["A"+str(i)]=""
    sheet["B"+str(i)]=""
    sheet["C"+str(i)]=""
    
workbook.save(filename=path)
