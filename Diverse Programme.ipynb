# %%
#konvertiere xlsx zu xlsm
import openpyxl

# Pfad zur XLSX-Datei angeben
xlsx_file_path = r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\example.xlsx"

# Pfad zur Ziel-XLSM-Datei angeben
xlsm_file_path = r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\example.xlsm"

# XLSX-Datei öffnen
workbook = openpyxl.load_workbook(xlsx_file_path)

# Arbeitsblätter mit Makros in XLSM konvertieren
for sheet in workbook.worksheets:
    if sheet.vba_code:
        sheet.vba_archive = workbook.vba_archive

# XLSM-Datei speichern
workbook.save(xlsm_file_path)

# %%
#teilt alle excel in dem ordner durch vier 
# überprüft den Abstand der Zeitreihen, sind die aufeinanderfolgenden Zeiten im 5 Minuten- oder 15 Minutentakt hinterlegt?
import os
import pandas as pd
import xlsxwriter
import datetime

# introduction of Datetime to access the time
now=datetime.datetime.now().strftime('%Y-%m-%d')

# setting display options for Jupyter output
pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 2)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 2000)

# directory of source files
path=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\Viertelstunden_Next"

for file in os.listdir(path):
    # list of months
    mon_list=[]
    # DataFrame for a month
    df_mon=pd.DataFrame([])
    csv_path=path+"\\"+file
    # reading a source file
    # numbers are separated by commas as decimal points
    df=pd.read_csv(csv_path, delimiter=";", decimal=",")

    path_neu = r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\VR_Neu"
    
    # dividing column [1] by 4
    df[df.columns[1]]=df[df.columns[1]].div(4)
    # splitting .csv as a filename
    file=file.split(".")
    file=file[0]
    path_vr= path_neu+"\\"+now+"_neu_"+"_"+file+".xlsx"
    df.to_excel(path_vr)
    list_series=df.iloc[:,0].tolist()
    mon_a=int(list_series[0].split(":")[1])
    mon_b=int(list_series[1].split(":")[1])
    print(mon_a)
    if mon_a-mon_b == 15:
        print("good")
    else:
        print(file +" bad")
    
    #except:
       # print("error")

# %%
#umbennenungstool python, ersetzt Jan-Mär mit Dez-Mär
import os
import shutil
old_string= "Jan-Mär"
new_string="Dez-Mär"
patha=r"U:\x Abschöpfung\Grundlagendaten Ben"
for file in os.listdir(patha):
    if old_string in file:
        new_filename=file.replace(old_string, new_string)
        print(new_filename)
        os.rename(os.path.join(patha, file), os.path.join(patha,new_filename))

# %%
#legt die Strom PBG Datei in allen Ziel-Ordnern ab
#ablege datei muss erst aktiviert werden, damit nix überschrieben wird

import os
import pandas as pd
import shutil
import datetime
name="StromPBG_Referenzberechnungstool_2023.03_V3"
# directory of source files
now=datetime.datetime.now().strftime('%Y-%m-%d')
path=r"U:\x Abschöpfung"
datei=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\{}.xlsx".format(name)
folder = os.listdir(path)
for file in folder:
    file_list=file.split(" ")
    print((file_list[0]))
    if int(file_list[0])>=0:
        print("größer")
        print(file)
       # os.remove(path+"\\"+file+"\\"+"2023-04-28"+" "+file+" {}.xlsx".format(name))
        dest_path=path+"\\"+file+"\\"+now+" "+file+"{}.xlsx".format(name)
        shutil.copyfile(datei,dest_path)
    else:
        print("kleiner")

# %%
#dieser Code zerschneidet eine PDF und teilt sie in Intervalle auf

from PyPDF2 import PdfWriter, PdfReader
import datetime

#Zeiteinheit wird gezogen
now=datetime.datetime.now().strftime('%Y-%m-%d')
len_p=5
path=r"C:\Users\benjamin.schmitz\Downloads\2023-04-20 50Hertz Transmission an Wattner - StromPBG - Information zum Registrierungsprozess bei 50Hertz Transmission.pdf"
#path=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\20221213_11h05 Uhr-Synopse-StromPBG_synops_20221213_110550.pdf"
inputpdf =PdfReader(open(path, "rb"))
outp_path=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\Output"
for i in range(0,len(inputpdf.pages),len_p):
    output=PdfWriter()
    for j in range(i, min(i+len_p, len(inputpdf.pages))):
        output.add_page(inputpdf.pages[j])
    with open(outp_path+"\\"+now+" Hertz Transmission an SKW {}-{} - StromPBG - Information zum Registrierungsprozess bei 50Hertz Transmission .pdf".format(i, i+(len_p)),"wb") as outputStream:
        output.write(outputStream)

# %%
#Überträgt Daten von einer Datei in eine andere


from openpyxl import load_workbook
import win32com.client as win32
excel = win32.Dispatch("Excel.Application")
#excel.Visible=True

for wb in excel.Workbooks:
                print("wb.name")
                print(wb.name)
                print("file")
                print(right_file)
                if wb.Name == right_file:
                    print("wb.Name == file:")
                    workbook = wb
                    break
if workbook is not None:
                    
    print("not None a")
    worksheet=workbook.Worksheets("Deckblatt")
    worksheet.Range("B9").Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
    worksheet.Range("P9").Value="aktiv"
    worksheet.Range("C2").Value=Mastr
    worksheet.Range("C9").Value=SEE[0]
    worksheet.Range("D9").Value=EEG[0]
    worksheet.Range("F9").Value=gesammt_kosten[0]
    #workbook.Save()
if len(SEE) >=2:
    print("not None b")
    
    worksheet=workbook.Worksheets("Deckblatt")
    worksheet.Range("B10").Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
    worksheet.Range("P10").Value="aktiv"
    worksheet.Range("C10").Value=SEE[1]
    worksheet.Range("D10").Value=EEG[1]
    worksheet.Range("F10").Value=gesammt_kosten[1]
if len(SEE) >=3:
    print("not None c")
    worksheet=workbook.Worksheets("Deckblatt")
    worksheet.Range("B11").Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
    worksheet.Range("P11").Value="aktiv"
    worksheet.Range("C11").Value=SEE[2]
    worksheet.Range("D11").Value=EEG[2]
    worksheet.Range("F11").Value=gesammt_kosten[2]
if len(SEE) >=4:
    print("not None d")
    worksheet=workbook.Worksheets("Deckblatt")
    worksheet.Range("P12").Value="aktiv"
    worksheet.Range("B12").Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
    worksheet.Range("C12").Value=SEE[3]
    worksheet.Range("D12").Value=EEG[3]
    worksheet.Range("F12").Value=gesammt_kosten[3]
if len(SEE) >=5:
    print("not None e")
    worksheet=workbook.Worksheets("Deckblatt")
    worksheet.Range("P13").Value="aktiv"
    worksheet.Range("B13").Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
    worksheet.Range("C13").Value=SEE[4]
    worksheet.Range("D13").Value=EEG[4]
    worksheet.Range("F13").Value=gesammt_kosten[4]

# %%
#right_file="2023-05-02 60 SchwarzheideStromPBG_Referenzberechnungstool_2023.02_V3.xlsx"

del SEE[0]
del EEG[0]
del gesammt_kosten[0]
Deckblatt

# %%
#Überträgt Daten von einer Datei in eine andere


from openpyxl import load_workbook
import win32com.client as win32

excel = win32.Dispatch("Excel.Application")
#path=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\ble.xlsx"
sheet_name="Deckblatt"

#excel.Visible=1
workbook = load_workbook(path_PBG_final)
#worksheet=workbook.Worksheets(sheet_name)


print(workbook)          
if workbook is not None:
                    
    print("not None a")
    worksheet=workbook.worksheets[2]
    worksheet["B9"]="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
    worksheet["P9"]="aktiv"
    worksheet["C2"]=Mastr
    worksheet["C9"]=SEE[0]
    worksheet["D9"]=EEG[0]
    worksheet["F9"]=gesammt_kosten[0]
    #workbook.Save()
if len(SEE) >=2:
    print("not None b")
    
    worksheet=workbook.worksheets[2]
    worksheet["B10"]="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
    worksheet["P10"]="aktiv"
    worksheet["C10"]=SEE[1]
    worksheet["D10"]=EEG[1]
    worksheet["F10"]=gesammt_kosten[1]
if len(SEE) >=3:
    print("not None c")
    worksheet=workbook.worksheets[2]
    worksheet["B11"]="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
    worksheet["P11"]="aktiv"
    worksheet["C11"]=SEE[2]
    worksheet["D11"]=EEG[2]
    worksheet["F11"]=gesammt_kosten[2]
if len(SEE) >=4:
    print("not None d")
    worksheet=workbook.worksheets[2]
    worksheet["P12"]="aktiv"
    worksheet["B12"]="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
    worksheet["C12"]=SEE[3]
    worksheet["D12"]=EEG[3]
    worksheet["F12"]=gesammt_kosten[3]
if len(SEE) >=5:
    print("not None e")
    worksheet=workbook.worksheets[2]
    worksheet["P13"].Value="aktiv"
    worksheet["B13"].Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
    worksheet["C13"].Value=SEE[4]
    worksheet["D13"].Value=EEG[4]
    worksheet["F13"].Value=gesammt_kosten[4]
    
workbook.save(path_PBG_final)

# %%
import win32com.client
excel = win32com.client.Dispatch("Excel.Application")

path=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\ble.xlsx"
workbook = excel.Workbooks.Open(path)
#excel.Visible=1

worksheet=workbook.Worksheets("Deckblatt")
worksheet.Range("B9").Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
worksheet.Range("P9").Value="aktiv"
worksheet.Range("C2").Value=Mastr
worksheet.Range("C9").Value=SEE[0]
worksheet.Range("D9").Value=EEG[0]
worksheet.Range("F9").Value=gesammt_kosten[0]
excel.Workbooks.Count


excel.Workbooks.Close()

# %%
#Überträgt Daten von einer Datei in eine andere
from openpyxl import load_workbook
import win32com.client
excel = win32com.client.Dispatch("Excel.Application")
#path=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\ble.xlsx"
workbook = excel.Workbooks.Open(path_PBG_final)

if workbook is not None:
                    
    print("not None a")
    worksheet=workbook.Worksheets("Deckblatt")
    worksheet.Range("B9").Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
    worksheet.Range("P9").Value="aktiv"
    worksheet.Range("C2").Value=Mastr
    worksheet.Range("C9").Value=SEE[0]
    worksheet.Range("D9").Value=EEG[0]
    worksheet.Range("F9").Value=gesammt_kosten[0]
    #workbook.Save()
    if len(SEE) >=2:
        print("not None b")

        worksheet=workbook.Worksheets("Deckblatt")
        worksheet.Range("B10").Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
        worksheet.Range("P10").Value="aktiv"
        worksheet.Range("C10").Value=SEE[1]
        worksheet.Range("D10").Value=EEG[1]
        worksheet.Range("F10").Value=gesammt_kosten[1]
    if len(SEE) >=3:
        print("not None c")
        worksheet=workbook.Worksheets("Deckblatt")
        worksheet.Range("B11").Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
        worksheet.Range("P11").Value="aktiv"
        worksheet.Range("C11").Value=SEE[2]
        worksheet.Range("D11").Value=EEG[2]
        worksheet.Range("F11").Value=gesammt_kosten[2]
    if len(SEE) >=4:
        print("not None d")
        worksheet=workbook.Worksheets("Deckblatt")
        worksheet.Range("P12").Value="aktiv"
        worksheet.Range("B12").Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
        worksheet.Range("C12").Value=SEE[3]
        worksheet.Range("D12").Value=EEG[3]
        worksheet.Range("F12").Value=gesammt_kosten[3]
    if len(SEE) >=5:
        print("not None e")
        worksheet=workbook.Worksheets("Deckblatt")
        worksheet.Range("P13").Value="aktiv"
        worksheet.Range("B13").Value="EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV"
        worksheet.Range("C13").Value=SEE[4]
        worksheet.Range("D13").Value=EEG[4]
        worksheet.Range("F13").Value=gesammt_kosten[4]
excel.Quit()

# %%
os.startfile(path_PBG_final)

# %%
#diese Programm öffnet mehrere Dateien in einem Ordner, kopiert Daten aus den Datein in einen Dataframe,
#zeigt den benannten Dataframe und vergleicht den Input miteinandern
import os
path_Absch =r"U:\x Abschöpfung"
no="02"
SEE= []
EEG= []
for i in os.listdir(path_Absch):
    if no in i:
        new_path=(path_Absch+"\\"+i)
        for j in os.listdir(new_path):
            if "StromPBG_Referenzberechnungstool" in j:
                print(j)
                PBG=pd.read_excel(new_path+"\\"+j, sheet_name="Deckblatt", header=7)
                display(PBG.head())
                if "EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV" in row["Auswahl Anwendungsfall §16 StromPBG\n(Dropdown)"]:
                    SEE.append(PGB_ben.loc[index,"MaStR-Nummer der Einheit \n(SEE-Nr.)"])
# Out:
# 2023-04-18 02 Pähl StromPBG_Referenzberechnungstool_2022_12_V1.xlsx
# C:\Users\benjamin.schmitz\Anaconda3\lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
#    lfd. Nr. Anlage Auswahl Anwendungsfall §16 StromPBG\n(Dropdown)  \
# 0                1   EEG-Anlage Solar MP (Abs. 1 Nr. 1) o. InnAusV
# 1                2                                 Bitte auswählen
# 2                3                                 Bitte auswählen
# 3                4                                 Bitte auswählen
# 4                5                                 Bitte auswählen
#
#   MaStR-Nummer der Einheit \n(SEE-Nr.)  \
# 0                      SEE920715701286
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# ...

# %%
#### öffnet zwei neue Dateien und schließt und speichert zwei Alte

import os
import shutil
import pandas as pd
import win32com.client

import time
path_grund=r"U:\x Abschöpfung\Grundlagendaten Ben"
path_PBG=r"U:\x Abschöpfung"
Einspeisung="Einspeisung\nkWh"

no1="28"
no2=" 0"+str(no1)
no3="SK0"+str(no1)
#neue nummer wird nach Nummerngröße vergeben, da unterschiedliche Bezeichnungen existieren
excel=win32com.client.Dispatch("Excel.Application")

vers="2022.12_V1"
path_markt_akt=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\2023-04-13 Wattner - Abschöpfung - Marktakteure.xlsx"
path_PBG_ben=r"C:\Users\benjamin.schmitz\OneDrive - Wattner\Desktop\2023-03-14 Wattner - Abschöpfung nach StromPBG Benb.xlsm"
Leistung_list=[]
SEE= []
EEG= []
Ref1=[]
MGM =[]
Einspeisung2=[]
gesammt_kosten=[]
prozent_Leistung=[]
Anlage=[]
name=[]
workbook = None
#die excel mit den marktakteuren wird eingelesen
markt_akt=pd.read_excel(path_markt_akt)#,sheet_name="2023-04-13 Wattner - Abschöpfung - Marktakteure
#die excel mit den anlagen wird eingelesen
PGB_ben=pd.read_excel(path_PBG_ben,sheet_name="Alle Anlagen", header=2)
for index, row in markt_akt.iterrows():
    #die Marktakteure werden geladen und die MaStR-Nr wird in einer Variabel hinterlegt
    if no2 in row["Name des Marktakteurs"]:
        Mastr= markt_akt.loc[index,"MaStR-Nr."]
        print(Mastr)
        
for index, row in PGB_ben.iterrows():
    if pd.isna(row["Anlagenbetreiber"]):
        continue
    if no3 in row["Anlagenbetreiber"]:
        SEE.append(PGB_ben.loc[index,"MaStR-Nr. der SEE:"])
        EEG.append(PGB_ben.loc[index,"MaStR-Nr. der EEG-Anlage:"])
        Ref1= PGB_ben.loc[index,"anzulegender Wert EUR/kWh (ohne Managementprämie)"]
        if Ref1 == "fällt raus, da < 1 MW":
            Ref1=0
        MGM = PGB_ben.loc[index,"Managementprämie EUR/kWh"]
        if MGM == "fällt raus, da < 1 MW":
            MGM=0
        Leistung_list.append((PGB_ben.loc[index,"DC-Leistung in kWp"]))
        gesammt_kosten.append(float(Ref1+MGM)*100)
        Name = str(row["Teilanlage"])+" "+str(row["Anlagenbetreiber"])
        name.append(Name)
        Einspeisung2.append(PGB_ben.loc[index,Einspeisung])
for i in Leistung_list:        
    prozent_Leistung.append(i/sum(Leistung_list))
#print(SEE)
#print(EEG)
#print(gesammt_kosten)      
#print(Leistung_list)
#print(sum(Leistung_list))
#print(prozent_Leistung)
#print(Mastr)
for file in os.listdir(path_grund):
    if no2 in file:
        new_path_gr = path_grund+"\\"+file
        print("grunddatei")
        print(file)
        os.startfile(new_path_gr)

for root, dirs, files in os.walk(path_PBG):
    # die Datei für die Abschöpfung wird geöffnet
    for file in files:
        #die Datei mit der richtigen Nummer und version erhält die richtigen nummern
        if str(no1) in file and vers in file and str(no1) in root:
            print("PGB Datei")
            print(root)
            print(file)
    
          
            path_PBG_final=os.path.join(root, file)
            #workbook = load_workbook(filename=path_PBG_final)
           #worksheet=workbook["Deckblatt"]
           #worksheet["C2"]=Mastr[0]
           #worksheet["C9"]=SEE[0]
           #worksheet["D9"]=EEG[0]
           #worksheet["F9"]=gesammt_kosten[0]
            
            #erhält$ zeichen, weil es aus walk genommen wurde?
            right_file = file
            print("Right_File")
            print(right_file)
           # right_file=right_file[2:]
           # workbook.save(filename=path_PBG_final)
            

         
            os.startfile(path_PBG_final)
            
Gesammelte_Daten=pd.DataFrame(list(zip(name, SEE, EEG,gesammt_kosten,Leistung_list,prozent_Leistung, Einspeisung2)), columns=["Name","SEE","EEG","Kosten","Leistung", "Leistung %","Einspeisung2"])
Gesammelte_Daten
# Out:
# ABR978228916871
# grunddatei
# 2023-04-18 028 Gefell Zeitreihe Dez-Mär.xlsx
# grunddatei
# 2023-04-18 028 Wittstock Zeitreihe Dez-Mär.xlsx
# grunddatei
# ~$2023-04-18 028 Wittstock Zeitreihe Dez-Mär.xlsx
#                                                Name              SEE  \
# 0                           PVA Gefell SK028 Gefell  SEE958350615408
# 1           Neustadt-Dosse Ost SK028 Neustadt-Dosse  SEE973786333467
# 2          Neustadt-Dosse West SK028 Neustadt-Dosse  SEE910529941404
# 3   Neustadt-Dosse Ost SKW 042 SK028 Neustadt-Dosse  SEE913114907106
# 4  Neustadt-Dosse West SKW 042 SK028 Neustadt-Dosse  SEE934553163199
# 5                   PVA Wittstock 1 SK028 Wittstock  SEE951052914367
# 6                   PVA Wittstock 2 SK028 Wittstock  SEE954415125356
#
#                EEG  Kosten  Leistung  Leistung %           Einspeisung2
# 0  EEG949966301687   18.34   9567.36    0.648857                63940.8
# ...

# %%
pd.set_option('display.max_columns', None)
PGB_ben.head()
# Out:
#   Nummer Anlagenbetreiber     Solarpark  \
# 0      1             DEWA  Harrenstätte
# 1      2             DEWA   Hoyerswerda
# 2      3             DEWA   Hoyerswerda
# 3      4             DEWA   Hoyerswerda
# 4      5             DEWA   Hoyerswerda
#
#                                           Teilanlage MaStR-Nr. der SEE:  \
# 0                                       Harrenstätte    SEE968770093830
# 1                Hoyerswerda 11 (Hufelandstr. 30-34)    SEE910630850862
# 2                 Hoyerswerda 10 (Hufelandstr. 7-11)    SEE926808727058
# 3  Hoyerswerda 14 (Käthe-Niederkirchner-Str. 12 (...    SEE993847721194
# 4   Hoyerswerda 07 (Ernst-Heim-Str. 22 (17-24 zug.))    SEE970998160713
#
#   MaStR-Nr. der EEG-Anlage:  Postleitzahl           Ort EEG-Inbetriebnahme  \
# 0           EEG992965639060       49751.0  Harrenstätte         2008-12-23
# 1           EEG914227292370        2977.0   Hoyerswerda         2009-12-17
# ...

# %%
display(Gesammelte_Daten)
print("lel")
# Out:
#                      Name              SEE              EEG  Kosten  Leistung  \
# 0  Lüttow-Valluhn 1 SK089  SEE958199118603  EEG905487778889    0.00    744.81
# 1  Lüttow-Valluhn 2 SK089  SEE954858698424  EEG970206383781    5.15   9219.54
# 2  Lüttow-Valluhn 3 SK089  SEE956936637561  EEG907688765170    4.83   6320.82
#
#    Leistung %           Einspeisung2
# 0    0.045735  fällt raus, da < 1 MW
# 1    0.566131                 599572
# 2    0.388133                 411047
# lel

# %%
#öffnet file mit bestimmtem namen
import os
import shutil
stat=0
search_string ="VNB 03.2023"
SKW="018"
path_skw=r"Z:\Belege 2023"
for folder in os.listdir(path_skw):
    if SKW in folder:
        new_path="Z:\Belege 2023"+"\\"+folder
        for root, dirs, files in os.walk(new_path):
           #print(type(files))
           #print(files)
            for file in files:
                #print(root)
                #print(file)
                if search_string in file:
                    #print(file)
                    final_path=os.path.join(root,file)
                    print(final_path)
                    os.startfile(final_path) 
                    stat=1
                    #os.startfile(root)
               
                     
if stat==0:
    print("Beleg nicht vorhanden")
    os.startfile(new_path)
# Out:
# Beleg nicht vorhanden

# %%
os.startfile(path_grund)
os.startfile(path_PBG)
os.startfile(r"U:\x Abschöpfung\_Tabellen Wattner")

# %%
#löscht bestimmte zeilen in einer Excel

from openpyxl import load_workbook
path=r"C:\Users\benjamin.schmitz\Downloads\zeitreihen-pv-wattner079-202303011400-202304011300.xlsx"
workbook = load_workbook(filename=path)


sheet = workbook.active

for i in range(2975, 2984):
    print(i)
    sheet["A"+str(i)]=""
    sheet["B"+str(i)]=""
    sheet["C"+str(i)]=""
    
for i in range(5950, 5965):
    print(i)
    sheet["A"+str(i)]=""
    sheet["B"+str(i)]=""
    sheet["C"+str(i)]=""
for i in range(8640, 8650):
    print(i)
    sheet["A"+str(i)]=""
    sheet["B"+str(i)]=""
    sheet["C"+str(i)]=""
    
workbook.save(filename=path)
# Out:
# 2975
# 2976
# 2977
# 2978
# 2979
# 2980
# 2981
# 2982
# 2983
# 5950
# 5951
# 5952
# 5953
# 5954
# 5955
# 5956
# 5957
# 5958
# 5959
# 5960
# 5961
# 5962
# 5963
# 5964
# 8640
# 8641
# 8642
# 8643
# 8644
# 8645
# 8646
# 8647
# 8648
# 8649
